# %%
import xarray as xr
from matplotlib import pyplot as plt
import numpy as np
from cartopy import crs as ccrs
import pandas as pd
import dask
import netCDF4

# %%
#For TAC 2020

external_data1 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202001.nc')
external_data2 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202002.nc')  
external_data3 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202003.nc')
external_data4 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202004.nc')
external_data5 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202005.nc')
external_data6 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202006.nc')
external_data7 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202007.nc')
external_data8 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202008.nc')
external_data9 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202009.nc')
external_data10 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202010.nc')
external_data11 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202011.nc')
external_data12 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202012.nc')


# Concatenate the datasets along the time dimension with explicit dimension specification
combined_data = xr.concat([external_data1, external_data2, external_data3, external_data4, external_data5, external_data6, external_data7, external_data8, external_data9, external_data10, external_data11, external_data12], dim='time', coords='minimal')

# Plotting
plt.figure(figsize=(20, 6))

# Plot combined external data
plt.plot(combined_data['time'], combined_data['fp'].mean(dim=('lat', 'lon')), label='Combined External Data', marker='o')
# Assuming 'lat' and 'lon' are dimensions in dataset

plt.title('Radon levels 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.show()

# %%
#Jan

fp_data1 = external_data1['fp']

# Plotting
plt.plot(fp_data1['time'], fp_data1.mean(dim=('lat', 'lon')), label='External Data 1', marker='o')

# Customize the plot
plt.title('Radon levels for January 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Feb

fp_data2 = external_data2['fp']

# Plotting
plt.plot(fp_data2['time'], fp_data2.mean(dim=('lat', 'lon')), label='External Data 2', marker='o')

# Customize the plot
plt.title('Radon levels for February 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#March

fp_data3 = external_data3['fp']

# Plotting
plt.plot(fp_data3['time'], fp_data3.mean(dim=('lat', 'lon')), label='External Data 3', marker='o')

# Customize the plot
plt.title('Radon levels for March 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#April

fp_data4 = external_data4['fp']

# Plotting
plt.plot(fp_data4['time'], fp_data4.mean(dim=('lat', 'lon')), label='External Data 4', marker='o')

# Customize the plot
plt.title('Radon levels for April 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#May

fp_data5 = external_data5['fp']

# Plotting
plt.plot(fp_data5['time'], fp_data5.mean(dim=('lat', 'lon')), label='External Data 5', marker='o')

# Customize the plot
plt.title('Radon levels for May 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#June

fp_data6 = external_data6['fp']

# Plotting
plt.plot(fp_data6['time'], fp_data6.mean(dim=('lat', 'lon')), label='External Data 6', marker='o')

# Customize the plot
plt.title('Radon levels for June 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#July

fp_data7 = external_data7['fp']

# Plotting
plt.plot(fp_data7['time'], fp_data7.mean(dim=('lat', 'lon')), label='External Data 7', marker='o')

# Customize the plot
plt.title('Radon levels for July 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Aug

fp_data8 = external_data8['fp']

# Plotting
plt.plot(fp_data8['time'], fp_data8.mean(dim=('lat', 'lon')), label='External Data 8', marker='o')

# Customize the plot
plt.title('Radon levels for August 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Sept

fp_data9 = external_data9['fp']

# Plotting
plt.plot(fp_data9['time'], fp_data9.mean(dim=('lat', 'lon')), label='External Data 9', marker='o')

# Customize the plot
plt.title('Radon levels for September 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Oct

fp_data10 = external_data10['fp']

# Plotting
plt.plot(fp_data10['time'], fp_data10.mean(dim=('lat', 'lon')), label='External Data 10', marker='o')

# Customize the plot
plt.title('Radon levels for October 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Nov

fp_data11 = external_data11['fp']

# Plotting
plt.plot(fp_data11['time'], fp_data11.mean(dim=('lat', 'lon')), label='External Data 11', marker='o')

# Customize the plot
plt.title('Radon levels for November 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Dec

fp_data12 = external_data12['fp']

# Plotting
plt.plot(fp_data12['time'], fp_data12.mean(dim=('lat', 'lon')), label='External Data 12', marker='o')

# Customize the plot
plt.title('Radon levels for December 2020')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#For TAC 2021

external_data11 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202101.nc')
external_data21 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202102.nc')  
external_data31 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202103.nc')
external_data41 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202104.nc')
external_data51 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202105.nc')
external_data61 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202106.nc')
external_data71 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202107.nc')
external_data81 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202108.nc')
external_data91 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202109.nc')
external_data101 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202110.nc')
external_data111 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202111.nc')
external_data121 = xr.open_dataset(r'C:\Users\wilse\Documents\Final_project\TAC-185magl_UKV_rn_EUROPE_202112.nc')


# Concatenate the datasets along the time dimension with explicit dimension specification
combined_data = xr.concat([external_data11, external_data21, external_data31, external_data41, external_data51, external_data61, external_data71, external_data81, external_data91, external_data101, external_data111, external_data121], dim='time', coords='minimal')

# Plotting
plt.figure(figsize=(20, 6))

# Plot combined external data
plt.plot(combined_data['time'], combined_data['fp'].mean(dim=('lat', 'lon')), label='Combined External Data', marker='o')
# Assuming 'lat' and 'lon' are dimensions in dataset

plt.title('Radon levels 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.show()

# %%
#Jan

fp_data11 = external_data11['fp']

# Plotting
plt.plot(fp_data11['time'], fp_data11.mean(dim=('lat', 'lon')), label='External Data 11', marker='o')

# Customize the plot
plt.title('Radon levels for January 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Feb

fp_data21 = external_data21['fp']

# Plotting
plt.plot(fp_data21['time'], fp_data21.mean(dim=('lat', 'lon')), label='External Data 21', marker='o')

# Customize the plot
plt.title('Radon levels for Febuary 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#MArch

fp_data31 = external_data31['fp']

# Plotting
plt.plot(fp_data31['time'], fp_data31.mean(dim=('lat', 'lon')), label='External Data 31', marker='o')

# Customize the plot
plt.title('Radon levels for March 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#April

fp_data41 = external_data41['fp']

# Plotting
plt.plot(fp_data41['time'], fp_data41.mean(dim=('lat', 'lon')), label='External Data 41', marker='o')

# Customize the plot
plt.title('Radon levels for April 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#May 

fp_data51 = external_data51['fp']

# Plotting
plt.plot(fp_data51['time'], fp_data51.mean(dim=('lat', 'lon')), label='External Data 51', marker='o')

# Customize the plot
plt.title('Radon levels for May 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#June

fp_data61 = external_data61['fp']

# Plotting
plt.plot(fp_data61['time'], fp_data61.mean(dim=('lat', 'lon')), label='External Data 61', marker='o')

# Customize the plot
plt.title('Radon levels for June 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#July

fp_data71 = external_data71['fp']

# Plotting
plt.plot(fp_data71['time'], fp_data71.mean(dim=('lat', 'lon')), label='External Data 71', marker='o')

# Customize the plot
plt.title('Radon levels for July 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#August

fp_data81 = external_data81['fp']

# Plotting
plt.plot(fp_data81['time'], fp_data81.mean(dim=('lat', 'lon')), label='External Data 81', marker='o')

# Customize the plot
plt.title('Radon levels for August 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Sept

fp_data91 = external_data91['fp']

# Plotting
plt.plot(fp_data91['time'], fp_data91.mean(dim=('lat', 'lon')), label='External Data 91', marker='o')

# Customize the plot
plt.title('Radon levels for Spetember 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Oct

fp_data101 = external_data101['fp']

# Plotting
plt.plot(fp_data101['time'], fp_data101.mean(dim=('lat', 'lon')), label='External Data 101', marker='o')

# Customize the plot
plt.title('Radon levels for October 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#Nov

fp_data111 = external_data111['fp']

# Plotting
plt.plot(fp_data111['time'], fp_data111.mean(dim=('lat', 'lon')), label='External Data 111', marker='o')

# Customize the plot
plt.title('Radon levels for November 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#December 

fp_data121 = external_data121['fp']

# Plotting
plt.plot(fp_data121['time'], fp_data121.mean(dim=('lat', 'lon')), label='External Data 121', marker='o')

# Customize the plot
plt.title('Radon levels for December, 2021')
plt.xlabel('Time')
plt.ylabel('Radon Footprint')
plt.legend()  
plt.grid(True)

plt.xticks(rotation=45)

# Show the plot
plt.show()
